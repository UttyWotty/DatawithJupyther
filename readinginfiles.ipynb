# %%
import pandas as pd

# %%
#dosya adinda shift+tab yaparsan, neler kullanilabilir gorebilirsin
df = pd.read_csv("DataSets/wiki.csv")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
#sona eklenen t, formati degistiriyor 
df = pd.read_csv("DataSets/wiki.txt")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
#araya virgul koyarak yeniden csv yi duzgun okutabiliriz
df2 = pd.read_table("DataSets/wiki.csv", sep = ',')
df2
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
#to show all the files , or as much as we want
pd.set_option('display.max_rows', 101)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
df2.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
#loc means location. 0dan basliyor ve listedeki yerlerini gosteriyor
df2.loc[94]
# Out:
# Rank                                     95
# Name                                   Nike
# Industry                            Apparel
# Revenue (USD millions)               46,710
# Revenue growth                         4.9%
# Employees                            79,100
# Headquarters              Beaverton, Oregon
# Name: 94, dtype: object

# %%
#index location 
df2.iloc[4]
# Out:
# Rank                                          5
# Name                         UnitedHealth Group
# Industry                             Healthcare
# Revenue (USD millions)                  324,162
# Revenue growth                            12.7%
# Employees                               400,000
# Headquarters              Minnetonka, Minnesota
# Name: 4, dtype: object

# %%
#filter it with columns . ilk 10 
df2[df2['Rank']<10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
#isin fonksiyonu ile istedigimiz herseyo ayri olarak secebiliyoruz 
spesific_companies = ['Apple', 'Amazon']
df2[df2['Name'].isin(spesific_companies)]
# Out:
#    Rank    Name                    Industry Revenue (USD millions)  \
# 1     2  Amazon  Retail and cloud computing                513,983
# 3     4   Apple        Electronics industry                394,328
#
#   Revenue growth  Employees           Headquarters
# 1           9.4%  1,540,000    Seattle, Washington
# 3           7.8%    164,000  Cupertino, California

# %%
#hangilerinde coorporation adi geciyor , 
#str. contain 
df2[df2['Name'].str.contains('Corporation')]
# Out:
#     Rank                     Name            Industry Revenue (USD millions)  \
# 8      9     McKesson Corporation              Health                276,711
# 9     10      Chevron Corporation  Petroleum industry                246,252
# 32    33       Target Corporation              Retail                109,120
# 58    59          RTX Corporation        Conglomerate                 67,074
# 89    90  Progressive Corporation           Insurance                 49,611
#
#    Revenue growth Employees                Headquarters
# 8            4.8%    48,500               Irving, Texas
# 9           51.6%    43,846       San Ramon, California
# 32           2.9%   440,000      Minneapolis, Minnesota
# 58           4.2%   182,000  Arlington County, Virginia
# 89           4.0%    55,063      Mayfield Village, Ohio

# %%
#indurstyye gore indexte siraladik , set_index
df2 = df2.set_index('Industry')
df2
# Out:
#                                     Rank                                 Name  \
# Industry
# Retail                                 1                              Walmart
# Retail and cloud computing             2                               Amazon
# Petroleum industry                     3                           ExxonMobil
# Electronics industry                   4                                Apple
# Healthcare                             5                   UnitedHealth Group
# Healthcare                             6                           CVS Health
# Conglomerate                           7                   Berkshire Hathaway
# Technology and cloud computing         8                             Alphabet
# Health                                 9                 McKesson Corporation
# Petroleum industry                    10                  Chevron Corporation
# Pharmacy wholesale                    11                              Cencora
# ...

# %%
#filter fonksiyonu ile indexe gore siralama . indexte hala indurstry var
df2.filter(items = ['Name', 'Headquarters'], axis =1)
# Out:
#                                                                    Name  \
# Industry
# Retail                                                          Walmart
# Retail and cloud computing                                       Amazon
# Petroleum industry                                           ExxonMobil
# Electronics industry                                              Apple
# Healthcare                                           UnitedHealth Group
# Healthcare                                                   CVS Health
# Conglomerate                                         Berkshire Hathaway
# Technology and cloud computing                                 Alphabet
# Health                                             McKesson Corporation
# Petroleum industry                                  Chevron Corporation
# Pharmacy wholesale                                              Cencora
# Retail                                                           Costco
# ...

# %%
df2.filter(items = ['Employees'], axis =1)
# Out:
#                                     Employees
# Industry
# Retail                              2,100,000
# Retail and cloud computing          1,540,000
# Petroleum industry                     62,000
# Electronics industry                  164,000
# Healthcare                            400,000
# Healthcare                            259,500
# Conglomerate                          383,000
# Technology and cloud computing        156,000
# Health                                 48,500
# Petroleum industry                     43,846
# Pharmacy wholesale                     41,500
# Retail                                304,000
# Technology and cloud computing        221,000
# Healthcare                             46,035
# Health insurance                       70,231
# Petroleum industry                     17,800
# Petroleum industry                     13,000
# Petroleum industry                      9,743
# Automotive industry                   173,000
# ...

# %%
df2.filter(like = 'Retail', axis =0)
# Out:
#                             Rank                Name Revenue (USD millions)  \
# Industry
# Retail                         1             Walmart                611,289
# Retail and cloud computing     2              Amazon                513,983
# Retail                        12              Costco                226,954
# Retail                        20      The Home Depot                157,403
# Retail                        24              Kroger                148,258
# Retail                        33  Target Corporation                109,120
# Retail                        39              Lowe's                 97,059
# Retail                        53          Albertsons                 77,650
# Retail                        80              Publix                 54,942
# Retail                        89                 TJX                 49,936
# Retail                        96            Best Buy                 46,298
#
# ...

# %%
df2.loc['Retail']
# Out:
#           Rank                Name Revenue (USD millions) Revenue growth  \
# Industry
# Retail       1             Walmart                611,289           6.7%
# Retail      12              Costco                226,954          15.8%
# Retail      20      The Home Depot                157,403           4.1%
# Retail      24              Kroger                148,258           7.5%
# Retail      33  Target Corporation                109,120           2.9%
# Retail      39              Lowe's                 97,059           0.8%
# Retail      53          Albertsons                 77,650           8.0%
# Retail      80              Publix                 54,942          13.5%
# Retail      89                 TJX                 49,936           2.9%
# Retail      96            Best Buy                 46,298          10.6%
#
#           Employees                 Headquarters
# Industry
# Retail    2,100,000        Bentonville, Arkansas
# ...

# %%
df2.iloc[3]
# Out:
# Rank                                          4
# Name                                      Apple
# Revenue (USD millions)                  394,328
# Revenue growth                             7.8%
# Employees                               164,000
# Headquarters              Cupertino, California
# Name: Electronics industry, dtype: object

# %%
#orderBy methooduyla yine ilk 10 u buluk 
df[df['Rank'] <10].sort_values(by='Rank',ascending = False)
# Out:
#    Rank                  Name                        Industry  \
# 8     9  McKesson Corporation                          Health
# 7     8              Alphabet  Technology and cloud computing
# 6     7    Berkshire Hathaway                    Conglomerate
# 5     6            CVS Health                      Healthcare
# 4     5    UnitedHealth Group                      Healthcare
# 3     4                 Apple            Electronics industry
# 2     3            ExxonMobil              Petroleum industry
# 1     2                Amazon      Retail and cloud computing
# 0     1               Walmart                          Retail
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 8                276,711           4.8%     48,500              Irving, Texas
# 7                282,836           9.8%    156,000  Mountain View, California
# 6                302,089           9.4%    383,000            Omaha, Nebraska
# ...
